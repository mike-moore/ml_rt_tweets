# %% [markdown]
# # Predicting the Sentiment of a Tweet
# This notebook will explore the use of two different machine learning models trained to predict the sentiment of any given Tweet.
#
# TODO define sentiment...scale of 0 to 1.0

# %% [markdown]
# ## Importing the Pre-Trained Models

# %%
import os, sys
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
sys.path.append(os.path.join(os.getcwd(),'src'))
from NaiveBayesTwitter import predict_tweet_sentiment as nb_predict_sentiment
from LstmTwitter import predict_tweet_sentiment as lstm_predict_sentiment
from LstmTwitter import data_dir

# %% [markdown]
# # Naive Bayes Model

# %% [markdown]
# ## Example Test Cases for Illustration

# %%
test_tweet = "I ordered just once from TerribleCo, they screwed up, never used the app again."
sentiment = nb_predict_sentiment(test_tweet)
print(f"Naive Bayes Sentiment Prediction : {sentiment:.2f}")
# Out:
# Naive Bayes Sentiment Prediction : 0.22

# %%
test_tweet = "I loved the show today! It was amazing."
sentiment = nb_predict_sentiment(test_tweet)
print(f"Naive Bayes Sentiment Prediction : {sentiment:.2f}")
# Out:
# Naive Bayes Sentiment Prediction : 0.76

# %%
test_tweet = "No idea."
sentiment = nb_predict_sentiment(test_tweet)
print(f"Naive Bayes Sentiment Prediction : {sentiment:.2f}")
# Out:
# Naive Bayes Sentiment Prediction : 0.57

# %%
test_tweet = "Good to see you yesterday. Let me know next time you're in town."
sentiment = nb_predict_sentiment(test_tweet)
print(f"Naive Bayes Sentiment Prediction : {sentiment:.2f}")
# Out:
# Naive Bayes Sentiment Prediction : 0.74

# %%
test_tweet = "You're a terrible pool player."
sentiment = nb_predict_sentiment(test_tweet)
print(f"Naive Bayes Sentiment Prediction : {sentiment:.2f}")
# Out:
# Naive Bayes Sentiment Prediction : 0.11

# %%
test_tweet = "I'm sick of waiting in line. I doubt this is going to be worth it."
sentiment = nb_predict_sentiment(test_tweet)
print(f"Naive Bayes Sentiment Prediction : {sentiment:.2f}")
# Out:
# Naive Bayes Sentiment Prediction : 0.13

# %% [markdown]
# ## Shortcomings of the Naive Bayes Model
# Here are a few test cases that show some of the shortcomings of the Naive Bayes model.

# %%
test_tweet = "I'm not happy to see you."
sentiment = nb_predict_sentiment(test_tweet)
print(f"Naive Bayes Sentiment Prediction : {sentiment:.2f}")
# Out:
# Naive Bayes Sentiment Prediction : 0.75

# %%
# show a few more edge cases

# %% [markdown]
# # Deep Learning Model - LSTM

# %% [markdown]
# ## Example Test Cases for Illustration

# %%
test_tweet = "Good to see you yesterday. Let me know next time you're in town."
sentiment = lstm_predict_sentiment(test_tweet)
print(f"LSTM Sentiment Prediction : {sentiment:.2f}")
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 276) for input KerasTensor(type_spec=TensorSpec(shape=(None, 276), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 50).
# LSTM Sentiment Prediction : 1.00

# %%
test_tweet = "I'm not happy to see you."
sentiment = lstm_predict_sentiment(test_tweet)
print(f"LSTM Sentiment Prediction : {sentiment:.2f}")
# Out:
# LSTM Sentiment Prediction : 0.01

# %% [markdown]
# ## Testing with a Sample Data Set

# %%
import pandas as pd
# Provide the sample data set to use
data_file = os.path.join(data_dir, 'sentiment140', 'training.1600000.processed.noemoticon.csv')
# Reading the dataset with no columns titles and with latin encoding 
df_raw = pd.read_csv(data_file, encoding = "ISO-8859-1", header=None)
 # As the data has no column titles, we will add our own
df_raw.columns = ["label", "time", "date", "query", "username", "text"]
# Show the first 5 rows of the dataframe.
# You can specify the number of rows to be shown as follows: df_raw.head(10)
df_raw.head()
# Out:
#    label        time                          date     query         username  \
# 0      0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2      0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3      0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4      0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                 text
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
# Remove every column except for the text and the label
df_raw = df_raw[['label', 'text']]
df_raw.head()
# Out:
#    label                                               text
# 0      0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1      0  is upset that he can't update his Facebook by ...
# 2      0  @Kenichan I dived many times for the ball. Man...
# 3      0    my whole body feels itchy and like its on fire
# 4      0  @nationwideclass no, it's not behaving at all....

# %% [markdown]
# This sample data set is huge (1,600,000 rows). For this demonstration, we can trim the data to $\frac{1}{100} $th of its original size. That still gives us 16,000 Tweets to analyze. Which is plenty for the purposes of this demonstration. We can also maintain the data balance while trimming the dataframe. This will let us have an equal distribution of positive/negative sentiment Tweets.

# %%
# Separating positive and negative rows
df_pos = df_raw[df_raw['label'] == 4]
df_neg = df_raw[df_raw['label'] == 0]
print(f"Original data set number of positive Tweets: {len(df_pos)}")
print(f"Original data set number of negative Tweets: {len(df_neg)}")
# Only retaining 1/100th of our data from each output group
df_pos = df_pos.iloc[:int(len(df_pos)/10000)]
df_neg = df_neg.iloc[:int(len(df_neg)/10000)]
print(f"Sample data set number of positive Tweets: {len(df_pos)}")
print(f"Sample data set number of negative Tweets: {len(df_neg)}")
# Join the positive and negative groups and store them back into a single dataframe
df = pd.concat([df_pos, df_neg])
df.head()
# Out:
# Original data set number of positive Tweets: 800000
# Original data set number of negative Tweets: 800000
# Sample data set number of positive Tweets: 80
# Sample data set number of negative Tweets: 80
#         label                                               text
# 800000      4       I LOVE @Health4UandPets u guys r the best!!
# 800001      4  im meeting up with one of my besties tonight! ...
# 800002      4  @DaRealSunisaKim Thanks for the Twitter add, S...
# 800003      4  Being sick can be really cheap when it hurts t...
# 800004      4    @LovesBrooklyn2 he has that effect on everyone

# %%
df['nb_sentiment'] = df['text'].apply(nb_predict_sentiment)
df['lstm_sentiment'] = df['text'].apply(lstm_predict_sentiment)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-fce5fa09eb7f> in <module>
#       1 breakpoint()
# ----> 2 df['nb_sentiment'] = df['text'].apply(nb_predict_sentiment)
#       3 df['lstm_sentiment'] = df['text'].apply(lstm_predict_sentiment)
#       4 df.head()
#
# <ipython-input-45-fce5fa09eb7f> in <module>
#       1 breakpoint()
# ----> 2 df['nb_sentiment'] = df['text'].apply(nb_predict_sentiment)
#       3 df['lstm_sentiment'] = df['text'].apply(lstm_predict_sentiment)
#       4 df.head()
#
# ~/.vscode-server/extensions/ms-python.python-2021.3.680753044/pythonFiles/lib/python/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_frame.py in trace_dispatch(self, frame, event, arg)
#    1020                     if is_line:
#    1021                         self.set_suspend(thread, step_cmd, original_step_cmd=info.pydev_original_step_cmd)
# -> 1022                         self.do_wait_suspend(thread, frame, event, arg)
#    1023                     elif is_return:  # return event
#    1024                         back = frame.f_back
#
# ~/.vscode-server/extensions/ms-python.python-2021.3.680753044/pythonFiles/lib/python/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_frame.py in do_wait_suspend(self, *args, **kwargs)
#     151
#     152     def do_wait_suspend(self, *args, **kwargs):
# --> 153         self._args[0].do_wait_suspend(*args, **kwargs)
#     154
#     155     # IFDEF CYTHON
#
# ~/.vscode-server/extensions/ms-python.python-2021.3.680753044/pythonFiles/lib/python/debugpy/_vendored/pydevd/pydevd.py in do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    1853
#    1854             with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1855                 keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    1856
#    1857         frames_list = None
#
# ~/.vscode-server/extensions/ms-python.python-2021.3.680753044/pythonFiles/lib/python/debugpy/_vendored/pydevd/pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    1888
#    1889             self.process_internal_commands()
# -> 1890             time.sleep(0.01)
#    1891
#    1892         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:

# %% [markdown]
# ### 10 Tweets with Highest Sentiment - NB

# %%
pd.set_option('display.max_colwidth', None)
top_ten_nb_tweets = df.sort_values(by=['nb_sentiment'], ascending=False)[:10]
top_ten_nb_tweets.head(10)
# Out:
#         label  \
# 800054      4
# 800035      4
# 800061      4
# 800002      4
# 800008      4
# 800020      4
# 800034      4
# 800014      4
# 800016      4
# 800079      4
#
#                                                                                                                                                     text  \
# 800054     @QuotableBuffy I got a bunch of Buffy songs too! One of my faves is &quot;Vivian&quot; by Nerf Herder, when Faith met Spike in Buffy's body.
# 800035                                              @hawaii808shellz hAhAHA!! omG! we wer bOth laughiN off d hOOk!  cuz das hOW we roLLL...ryt sheLdawg?
# 800061                                                               @fuzeb they are so serious too while singing like.. whoa  hehe lsd maybe? j/k lolol
# 800002         @DaRealSunisaKim Thanks for the Twitter add, Sunisa! I got to meet you once at a HIN show here in the DC area and you were a sweetheart.
# 800008                                                                                   @tommcfly ah, congrats mr fletcher for finally joining twitter
# 800020                                                                                 Didn't place in the Peeps contest but thanks for voting anyways.
# 800034                                                                                                  @wisdomous you're welcome. glad you enjoyed it.
# 800014  @LutheranLucciol Make sure you DM me if you post a link to that video! &lt;LOL&gt;So I don't miss it   Better get permission and blessing first?
# 800016                        @michellardi i really don't know. i think its Globe!  yeah! sana gumaling na ko para alam ko na din kung makakasama ako! )
# 800079                                                      @mattgalloway Thanks for the hook up with @CarlyRush and suggesting me again bro! you rock!
#
#         lstm_sentiment  nb_sentiment
# 800054        0.997290      0.999983
# 800035        0.841972      0.999094
# 800061        0.953605      0.998690
# 800002        0.972336      0.998607
# 800008        0.999225      0.998022
# 800020        0.839463      0.995750
# 800034        0.999851      0.994929
# 800014        0.985767      0.994149
# 800016        0.268277      0.992661
# 800079        0.667948      0.990486

# %% [markdown]
# ### 10 Tweets with Highest Sentiment - LSTM

# %%
top_ten_lstm_tweets = df.sort_values(by=['lstm_sentiment'], ascending=False)[:10]
top_ten_lstm_tweets.head(10)
# Out:
#         label  \
# 800057      4
# 800015      4
# 800078      4
# 800034      4
# 800062      4
# 800017      4
# 800053      4
# 800041      4
# 800056      4
# 800008      4
#
#                                                                                                                                               text  \
# 800057                                                                                                           uploading pictures on friendster
# 800015                                                                                                        Just added tweetie to my new iPhone
# 800078                                                                                     had a good tech meeting at clubZone - dinner was sushi
# 800034                                                                                            @wisdomous you're welcome. glad you enjoyed it.
# 800062                                                                                                              loving life... and loving you
# 800017                                                                                                  @nicolerichie: your picture is very sweet
# 800053          @ladygaga Can't wait to see ur hot ass in Austin! woot woot!!! annnd love the bob with purple, i went the royal color way as well
# 800041  @JonathanRKnight Hi Jon! Great to hear from you! See you on the cruise, I cannot wait! Hope all is well on the Knight bus!  You are loved!
# 800056                                                                        Morning Tweetland, a long day ahead! Hope everyone has a great day
# 800008                                                                             @tommcfly ah, congrats mr fletcher for finally joining twitter
#
#         lstm_sentiment  nb_sentiment
# 800057        0.999980      0.788164
# 800015        0.999963      0.897971
# 800078        0.999863      0.882736
# 800034        0.999851      0.994929
# 800062        0.999789      0.727590
# 800017        0.999703      0.711334
# 800053        0.999678      0.957558
# 800041        0.999443      0.907231
# 800056        0.999410      0.963194
# 800008        0.999225      0.998022

# %% [markdown]
# ### 10 Tweets with Lowest Sentiment - NB

# %%
bottom_ten_nb_tweets = df.sort_values(by=['nb_sentiment'], ascending=True)[:10]
bottom_ten_nb_tweets.head(10)
# Out:
#     label  \
# 44      0
# 42      0
# 39      0
# 55      0
# 16      0
# 65      0
# 60      0
# 35      0
# 76      0
# 48      0
#
#                                                                                                                                          text  \
# 44                             Falling asleep. Just heard about that Tracy girl's body being found. How sad  My heart breaks for that family.
# 42                                                  Sad, sad, sad. I don't know why but I hate this feeling  I wanna sleep and I still can't!
# 39                          Bed. Class 8-12. Work 12-3. Gym 3-5 or 6. Then class 6-10. Another day that's gonna fly by. I miss my girlfriend
# 55    @andywana Not sure what they are, only that they are PoS! As much as I want to, I dont think can trade away company assets sorry andy!
# 16                                              Hollis' death scene will hurt me severely to watch on film  wry is directors cut not out now?
# 65                                         @Starrbby too bad I won't be around I lost my job and can't even pay my phone bill lmao aw shucks
# 60                                     @BatManYNG I miss my ps3, it's out of commission  Wutcha playing? Have you copped 'Blood On The Sand'?
# 35            ok I'm sick and spent an hour sitting in the shower cause I was too sick to stand and held back the puke like a champ. BED now
# 76  @ashleyac My donkey is sensitive about such comments. Nevertheless, he'd (and me'd) be glad to see your mug asap. Charger is still awol.
# 48                                                                                        is strangely sad about LiLo and SamRo breaking up.
#
#     lstm_sentiment  nb_sentiment
# 44        0.100498      0.000105
# 42        0.000011      0.000178
# 39        0.015455      0.000367
# 55        0.010563      0.000494
# 16        0.044554      0.000991
# 65        0.019793      0.001098
# 60        0.014642      0.001463
# 35        0.044630      0.001658
# 76        0.321593      0.001980
# 48        0.000133      0.002354

# %% [markdown]
# ### 10 Tweets with Lowest Sentiment - LSTM

# %%
bottom_ten_lstm_tweets = df.sort_values(by=['lstm_sentiment'], ascending=True)[:20]
bottom_ten_lstm_tweets.head(20)
# Out:
#     label  \
# 42      0
# 1       0
# 75      0
# 48      0
# 23      0
# 66      0
# 58      0
# 43      0
# 79      0
# 27      0
# 49      0
# 56      0
# 0       0
# 21      0
# 74      0
# 25      0
# 31      0
# 4       0
# 29      0
# 46      0
#
#                                                                                                                                           text  \
# 42                                                   Sad, sad, sad. I don't know why but I hate this feeling  I wanna sleep and I still can't!
# 1                              is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!
# 75                                                                                                     No picnic  my phone smells like citrus.
# 48                                                                                         is strangely sad about LiLo and SamRo breaking up.
# 23                                                                                                      this week is not going as i had hoped
# 66                                                                                                               Damm back to school tomorrow
# 58                                                                                                                 Ugh....92 degrees tomorrow
# 43                                       @JonathanRKnight Awww I soo wish I was there to see you finally comfortable! Im sad that I missed it
# 79                                           wonders why someone that u like so much can make you so unhappy in a split seccond . depressed .
# 27                                                                                                                      im sad now  Miss.Lilly
# 49                                                                         @tea oh! i'm so sorry  i didn't think about that before retweeting.
# 56                                                                                                      @oanhLove I hate when that happens...
# 0                          @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 21                                       one of my friend called me, and asked to meet with her at Mid Valley today...but i've no time *sigh*
# 74                                                                                 Why won't you show my location?!   http://twitpic.com/2y2es
# 25                                                                                              I hate when I have to call and wake people up
# 31         @alielayus I want to go to promote GEAR AND GROOVE but unfornately no ride there  I may b going to the one in Anaheim in May though
# 4                              @nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there.
# 29                                                           Meh... Almost Lover is the exception... this track gets me depressed every time.
# 46  Just checked my user timeline on my blackberry, it looks like the twanking is still happening  Are ppl still having probs w/ BGs and UIDs?
#
#     lstm_sentiment  nb_sentiment
# 42        0.000011      0.000178
# 1         0.000017      0.005633
# 75        0.000074      0.453582
# 48        0.000133      0.002354
# 23        0.000276      0.313808
# 66        0.000698      0.054309
# 58        0.001214      0.083526
# 43        0.001334      0.003522
# 79        0.001370      0.004687
# 27        0.002518      0.023385
# 49        0.002697      0.079629
# 56        0.003142      0.074737
# 0         0.004166      0.007692
# 21        0.004197      0.387669
# 74        0.004268      0.483575
# 25        0.004318      0.105116
# 31        0.004702      0.159894
# 4         0.006015      0.207310
# 29        0.006886      0.008491
# 46        0.009553      0.026884
